# %% [markdown]
# ## Data Science Capstone Project
#
# ### The Battle of the Neighbourhoods (Los Angeles) by [Prosper Nnaeto]

# %% [markdown]
# ## <u>Data</u> <a name="data"></a>

# %% [markdown]
# Based on the criteria specified above, the factors that will influence the final decision are: -
# * Number of existing restaurants in the neighbourhood (any type of restaurant)
# * Number of and distance to Italian restaurants in the neighbourhood
# * Distance of neighbourhood from city center
# * Average neighbourhood rent
#
# The following data sources will be needed to extract/generate the required information: -
# * List of all neighbourhoods in LA - https://en.wikipedia.org/wiki/List_of_districts_and_neighbourhoods_of_Los_Angeles
# * Coordinates of all neighbourhoods and venues - **GeoPy Nominatim geocoding**
# * Number of restaurants and their type and location in every neighbourhood - **Foursquare API** -  https://developer.foursquare.com
# * LA rent data - https://www.rentcafe.com/average-rent-market-trends/us/ca/los-angeles/

# %% [markdown]
# ## <u>Methodology</u><a name="methodology"></a>

# %% [markdown]
# <p style='text-align: justify;'>In this project the first step will be to collect data on the neighbourhoods of Los Angeles from the internet. There are no relevant datasets available for this and therefore, data will need to be scraped from a webpage. The location coordinates of each neighbourhood will then be obtained with the help of GeoPy Nominatim geolocator and appended to the neighbourhood data. Using this data, a folium map of the Los Angeles neighbourhoods will be created.</p>
#
# <p style='text-align: justify;'>The second step will be to explore each of neighbourhoods and their venues using Foursquare location data. The venues of the neighbourhoods will be analyzed in detail and patterns will be discovered. This discovery of patterns will be carried out by grouping the neighbourhoods using k-means clustering. Following this, each cluster will be examined and a decision will be made regarding which cluster fits the shareholder's requirements. The factor that will determine this is the frequency of occurrence of restaurants and other food venues within the cluster.</p>
#
# <p style='text-align: justify;'>Once a cluster is picked, the neighbourhoods in that cluster will be investigated with regards to the number of Vegan/vegetarian restaurants in its vicinity. The ones that fit the requirements will be further explored and shortlisted based on how small their respective distances to the center or Los Angeles are. Finally, if there are multiple neighbourhoods that fit these conditions, Los Angeles rent data can be used to influence the shareholder's decision. </p>
#
# <p style='text-align: justify;'>The results of the analysis will highlight potential neighbourhoods where vegan/vegetarian restaurant may be opened based on geographical location and proximity to competitors. This will only serve as a starting point since there are a lot of other factors that influence such a decision. </p>

# %% [markdown]
# ## <u>Analysis</u><a name="analysis"></a>

# %% [markdown]
# * [Importing Libraries](#import)
# * [Web Scraping Neighbourhood Data ](#scrapenh)
# * [Loading and Cleaning Neighbourhood ](#clean)
# * [Obtaining Neighbourhood Coordinates  ](#coordinates)
# * [ LA Neighbourhood Map ](#lamap)
# * [Defining Foursquare Credentials and Version  ](#foursquare)
# * [ Exploring the first Neighbourhood ](#first)
# * [Exploring all Neighbourhoods  ](#all)
# * [Analyzing each Neighbourhood  ](#analyze)
# * [Clustering Neighbourhoods  ](#cluster)
# * [Examining the Clusters  ](#examine)
# * [Visualizing Top 10 Venues for each Cluster  ](#visualize)
# * [Investigating the chosen Cluster  ](#investigate)
# * [Web Scraping Rent Data  ](#rent)

# %% [markdown]
# ### Importing Libraries <a name="import"></a>

# %% [markdown]
# The first step in the analysis is importing the required libraries.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas data frame

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

from bs4 import BeautifulSoup

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ca-certificates-2020.4.5.2 |       hecda079_0         147 KB  conda-forge
#     certifi-2020.4.5.2         |   py36h9f0ad1d_0         152 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0           conda-forge
#     geopy:           1.22.0-pyh9f0ad1d_0 conda-forge
#     python_abi:      3.6-1_cp36m         conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                      --> 2020.4.5.2-hecda079_0     conda-forge
#     certifi:         2020.4.5.1-py36_0               --> 2020.4.5.2-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0               --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# ca-certificates-2020 | 147 KB    | ##################################### | 100%
# certifi-2020.4.5.2   | 152 KB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
import re

# %% [markdown]
# ### Web Scraping Neighbourhood Data <a name="scrapenh"></a>

# %% [markdown]
# The list of all neighbourhoods in LA is obtained by scraping the relevant webpage. The data in the webpage is in the form of a list and not a table. Therefore, the data is obtained by searching for all list items and then using a particular characteristic that groups the required items.

# %%
url = requests.get('https://en.wikipedia.org/wiki/List_of_districts_and_neighbourhoods_of_Los_Angeles').text
soup = BeautifulSoup(url,"html.parser")

# %%
lis = []
for li in soup.findAll('li'):
    if li.find(href="/wiki/Portal:Los_Angeles"):
        break
    if li.find(href=re.compile("^/wiki/")):
        lis.append(li)
    if li.text=='Pico Robertson[34]': #Pico Robertson is the only item on the list that does not have a hyperlink reference
        lis.append(li)

# %% [markdown]
# ### Loading and Cleaning Neighbourhood <a name="clean"></a>

# %%
neigh = []
for i in range(0,len(lis)):
    neigh.append(lis[i].text.strip())
    
df = pd.DataFrame(neigh)
df.columns = ['Neighbourhood']

# %%
df
# Out:
#                                  Neighbourhood
# 0                          Angelino Heights[1]
# 1                                 Angeles Mesa
# 2                                Angelus Vista
# 3                                 Arleta[2][1]
# 4                         Arlington Heights[2]
# 5                             Arts District[3]
# 6                           Atwater Village[2]
# 7                             Baldwin Hills[1]
# 8                    Baldwin Hills/Crenshaw[2]
# 9                           Baldwin Village[1]
# 10                            Baldwin Vista[4]
# 11                         Beachwood Canyon[5]
# 12   Bel Air, Bel-Air or Bel Air Estates[2][1]
# 13                          Benedict Canyon[6]
# 14                            Beverly Crest[2]
# 15                             Beverly Glen[1]
# 16                            Beverly Grove[2]
# 17                Beverly Hills Post Office[7]
# 18                             Beverly Park[8]
# 19                              Beverlywood[2]
# 20                         Boyle Heights[2][1]
# 21                             Brentwood[2][1]
# 22                         Brentwood Circle[9]
# 23                          Brentwood Glen[10]
# 24                      Broadway-Manchester[2]
# 25                                   Brookside
# 26                              Bunker Hill[3]
# 27                            Cahuenga Pass[1]
# 28                           Canoga Park[2][1]
# 29                       Canterbury Knolls[11]
# 30                                  Carthay[2]
# 31                              Castle Heights
# 32                          Central-Alameda[2]
# 33                             Central City[1]
# 34                          Century City[2][1]
# 35                            Chatsworth[2][1]
# 36                   Chesterfield Square[2][1]
# 37                         Cheviot Hills[2][1]
# 38                             Chinatown[2][1]
# 39                            Civic Center[12]
# 40                                 Crenshaw[1]
# 41                         Crestwood Hills[13]
# 42                          Cypress Park[2][1]
# 43                               Del Rey[2][1]
# 44                                 Downtown[2]
# 45                            Eagle Rock[1][2]
# 46          East Gate Bel Air[citation needed]
# 47                           East Hollywood[2]
# 48                         East Los Angeles[2]
# 49                             Echo Park[2][1]
# 50                                Edendale[14]
# 51                             El Sereno[2][1]
# 52                         Elysian Heights[15]
# 53                             Elysian Park[2]
# 54                           Elysian Valley[2]
# 55                                Encino[2][1]
# 56                       Exposition Park[2][1]
# 57                      Faircrest Heights [16]
# 58                                  Fairfax[2]
# 59                         Fashion District[3]
# 60                  Filipinotown, Historic[17]
# 61                       Financial District[3]
# 62                              Florence[2][1]
# 63                         Flower District[18]
# 64                          Franklin Hills[19]
# 65                              Gallery Row[3]
# 66                                 Garvanza[1]
# 67                         Glassell Park[2][1]
# 68                            Gramercy Park[2]
# 69                         Granada Hills[2][1]
# 70                            Green Meadows[2]
# 71                            Griffith Park[2]
# 72                          Hancock Park[2][1]
# 73                           Harbor City[2][1]
# 74                        Harbor Gateway[2][1]
# 75                       Harvard Heights[2][1]
# 76                             Harvard Park[2]
# 77                                   Hermon[1]
# 78                         Highland Park[2][1]
# 79                            Historic Core[3]
# 80                             Hollywood[2][1]
# 81                          Hollywood Dell[20]
# 82                       Hollywood Hills[2][1]
# 83                     Hollywood Hills West[2]
# 84                             Holmby Hills[1]
# 85                             Hyde Park[2][1]
# 86                        Jefferson Park[2][1]
# 87                        Jewelry District[21]
# 88                          Kinney Heights[22]
# 89                             Koreatown[2][1]
# 90                              Ladera[23][24]
# 91                         Lafayette Square[1]
# 92                           Lake Balboa[2][1]
# 93                     Lake View Terrace[2][1]
# 94                                Larchmont[2]
# 95                           Laurel Canyon[25]
# 96                          Leimert Park[2][1]
# 97                       Lincoln Heights[2][1]
# 98                       Little Armenia[1][26]
# 99                         Little Ethiopia[27]
# 100                            Little Tokyo[1]
# 101                            Los Feliz[2][1]
# 102                       Manchester Square[2]
# 103                      Mandeville Canyon[28]
# 104                       Marina Peninsula[29]
# 105                            Mar Vista[2][1]
# 106                           Melrose Hill[30]
# 107                             Mid-City[2][1]
# 108                            Mid-Wilshire[2]
# 109                            Miracle Mile[1]
# 110                        Mission Hills[2][1]
# 111                    Montecito Heights[2][1]
# 112                         Monterey Hills[31]
# 113                           Mount Olympus[1]
# 114                     Mount Washington[2][1]
# 115                         Nichols Canyon[32]
# 116                     NoHo Arts District[33]
# 117                          North Hills[2][1]
# 118                      North Hollywood[2][1]
# 119                           Northridge[2][1]
# 120                   North University Park[1]
# 121                       Old Bank District[3]
# 122                        Outpost Estates[34]
# 123                    Pacific Palisades[2][1]
# 124                              Pacoima[2][1]
# 125                                Palms[2][1]
# 126                        Panorama City[2][1]
# 127                            Park La Brea[1]
# 128                        Picfair Village[35]
# 129                              Pico-Union[2]
# 130         Platinum Triangle[citation needed]
# 131                           Playa del Rey[1]
# 132                             Playa Vista[2]
# 133                         Porter Ranch[2][1]
# 134                          Rancho Park[2][1]
# 135                               Reseda[2][1]
# 136                        Reynier Village[37]
# 137                                 Rose Hills
# 138                          Rustic Canyon[38]
# 139                            San Pedro[2][1]
# 140                             Sawtelle[2][1]
# 141                         Shadow Hills[2][1]
# 142                         Sherman Oaks[2][1]
# 143                      Sherman Village[2][1]
# 144                          Silver Lake[2][1]
# 145                               Skid Row[39]
# 146                          Solano Canyon[40]
# 147                 South Central, Historic[2]
# 148                              South Park[2]
# 149                         South Robertson[1]
# 150                       Spaulding Square[41]
# 151                          Studio City[2][1]
# 152                              Sunland[2][1]
# 153                            Sunset Junction
# 154                           Sun Valley[2][1]
# 155                               Sylmar[2][1]
# 156                              Tarzana[2][1]
# 157                         Terminal Island[1]
# 158                               Thai Town[1]
# 159                          Toluca Lake[2][1]
# 160                            Toy District[3]
# 161                              Tujunga[2][1]
# 162                       University Hills[42]
# 163                         University Park[2]
# 164                  University Park, North[1]
# 165                          Valley Glen[2][1]
# 166                       Valley Village[2][1]
# 167                             Van Nuys[2][1]
# 168                               Venice[2][1]
# 169                       Vermont Knolls[2][1]
# 170                         Vermont-Slauson[2]
# 171                          Vermont Square[2]
# 172                           Vermont Vista[2]
# 173                         Victor Heights[43]
# 174                          Victoria Park[44]
# 175                          Village Green[45]
# 176                     Warehouse District[46]
# 177                           Warner Center[1]
# 178                                Watts[2][1]
# 179                           West Adams[2][1]
# 180                          Westchester[2][1]
# 181                               Westdale[47]
# 182                        Western Heights[48]
# 183                           West Hills[2][1]
# 184                             Westlake[2][1]
# 185                     West Los Angeles[2][1]
# 186                       Westside Village[49]
# 187                             Westwood[2][1]
# 188                       Westwood Village[50]
# 189                         Whitley Heights[1]
# 190                      Wholesale District[3]
# 191                           Wilmington[2][1]
# 192                         Wilshire Center[1]
# 193                          Wilshire Park[51]
# 194                       Windsor Square[2][1]
# 195                             Winnetka[2][1]
# 196                       Woodland Hills[2][1]
# 197                         Yucca Corridor[52]

# %%
df['Neighbourhood'] = df.Neighbourhood.str.partition('[')[0] #Removes the citation and reference brackets
df['Neighbourhood'] = df.Neighbourhood.str.partition(',')[0] #Removes the alternatives for 'Bel Air'
df=df[df.Neighbourhood!='Baldwin Hills/Crenshaw'] #Removes redundancy as 'Baldwin Hills' and 'Crenshaw' exist already
df=df[df.Neighbourhood!='Hollywood Hills West'] #Removes redundancy as it has the same coordinates as 'Hollywood Hills'
df=df[df.Neighbourhood!='Brentwood Circle'] #Removes redundancy as it has the same coordinates as 'Brentwood'
df=df[df.Neighbourhood!='Wilshire Park'] #Removes redundancy as it has the same coordinates as 'Wilshire Center'
df.reset_index(inplace=True,drop=True)

# %% [markdown]
# ### Obtaining Neighbourhood Coordinates  <a name="coordinates"></a>

# %%
# define the data frame columns
column_names = ['Neighbourhood', 'Latitude', 'Longitude'] 

# instantiate the data frame
nhoods = pd.DataFrame(columns=column_names)

# %% [markdown]
# Using GeoPy Nominatim geolocator with the user_agent "la_explorer".

# %%
geolocator = Nominatim(user_agent="la_explorer",timeout=5)
for i in range(0,len(df)):
    
    address = df.Neighbourhood[i]+', Los Angeles'
    location = geolocator.geocode(address)
    if location == None:
        latitude = 0
        longitude = 0
    else:
        latitude = location.latitude
        longitude = location.longitude

    nhoods = nhoods.append({'Neighbourhood': df.Neighbourhood[i],
                                              'Latitude': latitude,
                                              'Longitude': longitude}, ignore_index=True)

# %% [markdown]
# Clean neighbourhood data with the respective coordinates: -

# %%
nhoods
# Out:
#                  Neighbourhood   Latitude   Longitude
# 0             Angelino Heights  34.070289 -118.254796
# 1                 Angeles Mesa  33.991402 -118.319520
# 2                Angelus Vista   0.000000    0.000000
# 3                       Arleta  34.241327 -118.432205
# 4            Arlington Heights  34.043494 -118.321374
# 5                Arts District  34.041239 -118.234450
# 6              Atwater Village  34.118698 -118.262392
# 7                Baldwin Hills  34.010989 -118.337071
# 8              Baldwin Village  34.019456 -118.345910
# 9                Baldwin Vista   0.000000    0.000000
# 10            Beachwood Canyon  34.122292 -118.321384
# 11                     Bel Air  34.098883 -118.459881
# 12             Benedict Canyon  34.044770 -118.400022
# 13               Beverly Crest  34.116770 -118.432261
# 14                Beverly Glen  34.107785 -118.445636
# 15               Beverly Grove  34.076034 -118.369972
# 16   Beverly Hills Post Office  34.069650 -118.396306
# 17                Beverly Park  34.063769 -118.264690
# 18                 Beverlywood  34.046633 -118.395038
# 19               Boyle Heights  34.043689 -118.209768
# 20                   Brentwood  34.052140 -118.474070
# 21              Brentwood Glen   0.000000    0.000000
# 22         Broadway-Manchester  33.941015 -118.274404
# 23                   Brookside  14.587560  121.124733
# 24                 Bunker Hill  34.055066 -118.251223
# 25               Cahuenga Pass  34.096867 -118.329508
# 26                 Canoga Park  34.201078 -118.597826
# 27           Canterbury Knolls  33.842760 -118.129731
# 28                     Carthay  34.061121 -118.367300
# 29              Castle Heights   0.000000    0.000000
# 30             Central-Alameda  34.004015 -118.247784
# 31                Central City  34.053691 -118.242767
# 32                Century City  34.057426 -118.414727
# 33                  Chatsworth  34.259571 -118.602325
# 34         Chesterfield Square  33.983474 -118.313651
# 35               Cheviot Hills  34.040588 -118.409887
# 36                   Chinatown  34.063840 -118.235868
# 37                Civic Center  34.057561 -118.246810
# 38                    Crenshaw  33.925212 -118.326530
# 39             Crestwood Hills  34.076675 -118.488970
# 40                Cypress Park  34.092232 -118.224518
# 41                     Del Rey  33.989653 -118.424344
# 42                    Downtown  34.042849 -118.247673
# 43                  Eagle Rock  34.136688 -118.207680
# 44           East Gate Bel Air   0.000000    0.000000
# 45              East Hollywood  34.090428 -118.296625
# 46            East Los Angeles  34.023902 -118.172016
# 47                   Echo Park  34.077982 -118.256782
# 48                    Edendale  34.107516 -118.265949
# 49                   El Sereno  34.081121 -118.177849
# 50             Elysian Heights  34.099548 -118.244715
# 51                Elysian Park  34.077434 -118.238620
# 52              Elysian Valley  34.095913 -118.242033
# 53                      Encino  34.159132 -118.501617
# 54             Exposition Park  34.013654 -118.287211
# 55          Faircrest Heights    0.000000    0.000000
# 56                     Fairfax  34.079155 -118.352284
# 57            Fashion District  34.036622 -118.259069
# 58                Filipinotown   0.000000    0.000000
# 59          Financial District  34.050248 -118.255775
# 60                    Florence  33.974159 -118.243286
# 61             Flower District  34.040964 -118.249397
# 62              Franklin Hills  14.587560  121.124733
# 63                 Gallery Row  34.046687 -118.249490
# 64                    Garvanza  34.119578 -118.180626
# 65               Glassell Park  34.116120 -118.228963
# 66               Gramercy Park  33.951194 -118.309327
# 67               Granada Hills  34.266156 -118.517434
# 68               Green Meadows  33.940988 -118.262997
# 69               Griffith Park  34.134427 -118.305092
# 70                Hancock Park  34.073678 -118.335055
# 71                 Harbor City  33.797282 -118.300472
# 72              Harbor Gateway  33.854225 -118.299220
# 73             Harvard Heights  34.047111 -118.305483
# 74                Harvard Park  33.983947 -118.304623
# 75                      Hermon  34.107314 -118.185251
# 76               Highland Park  34.109947 -118.196983
# 77               Historic Core  34.045962 -118.251874
# 78                   Hollywood  34.098003 -118.329523
# 79              Hollywood Dell   0.000000    0.000000
# 80             Hollywood Hills  34.131179 -118.335547
# 81                Holmby Hills   0.000000    0.000000
# 82                   Hyde Park  33.985402 -118.330861
# 83              Jefferson Park  34.029617 -118.322460
# 84            Jewelry District  34.046206 -118.254167
# 85              Kinney Heights   0.000000    0.000000
# 86                   Koreatown  34.061734 -118.305373
# 87                      Ladera  33.994179 -118.375354
# 88            Lafayette Square   0.000000    0.000000
# 89                 Lake Balboa  34.181166 -118.495236
# 90           Lake View Terrace  34.276391 -118.361191
# 91                   Larchmont  34.079837 -118.317870
# 92               Laurel Canyon  34.168465 -118.396296
# 93                Leimert Park  34.007702 -118.332063
# 94             Lincoln Heights  34.070929 -118.209890
# 95              Little Armenia  34.098172 -118.304497
# 96             Little Ethiopia   0.000000    0.000000
# 97                Little Tokyo  34.048217 -118.241181
# 98                   Los Feliz  34.107656 -118.287506
# 99           Manchester Square  33.966374 -118.313378
# 100          Mandeville Canyon  34.061039 -118.494980
# 101           Marina Peninsula  33.748713 -118.122711
# 102                  Mar Vista  34.003760 -118.439164
# 103               Melrose Hill  14.587560  121.124733
# 104                   Mid-City  34.041527 -118.360370
# 105               Mid-Wilshire  34.056862 -118.345803
# 106               Miracle Mile   0.000000    0.000000
# 107              Mission Hills  34.257225 -118.467028
# 108          Montecito Heights  34.089540 -118.194279
# 109             Monterey Hills  34.104176 -118.164238
# 110              Mount Olympus  34.060368 -117.947829
# 111           Mount Washington  34.098840 -118.221107
# 112             Nichols Canyon  34.109307 -118.361017
# 113         NoHo Arts District   0.000000    0.000000
# 114                North Hills  34.242958 -118.485408
# 115            North Hollywood  34.172904 -118.374037
# 116                 Northridge  34.234561 -118.536932
# 117      North University Park   0.000000    0.000000
# 118          Old Bank District  14.623036  121.042219
# 119            Outpost Estates   0.000000    0.000000
# 120          Pacific Palisades  34.048064 -118.526471
# 121                    Pacoima  34.262502 -118.427027
# 122                      Palms  34.024733 -118.411615
# 123              Panorama City  34.224290 -118.445374
# 124               Park La Brea  34.067402 -118.355236
# 125            Picfair Village   0.000000    0.000000
# 126                 Pico-Union  34.046567 -118.287894
# 127          Platinum Triangle  34.465661 -118.569341
# 128              Playa del Rey  33.955083 -118.436750
# 129                Playa Vista  33.975957 -118.418182
# 130               Porter Ranch  34.281816 -118.561271
# 131                Rancho Park  34.034446 -118.425263
# 132                     Reseda  34.200078 -118.536988
# 133            Reynier Village   0.000000    0.000000
# 134                 Rose Hills  14.587560  121.124733
# 135              Rustic Canyon  34.077997 -118.519128
# 136                  San Pedro  33.735852 -118.292293
# 137                   Sawtelle  34.036111 -118.450356
# 138               Shadow Hills  34.261947 -118.351746
# 139               Sherman Oaks  34.150872 -118.448987
# 140            Sherman Village   0.000000    0.000000
# 141                Silver Lake  34.089652 -118.269374
# 142                   Skid Row  34.044057 -118.243851
# 143              Solano Canyon  34.081887 -118.234983
# 144              South Central -17.542618  -62.874624
# 145                 South Park  34.040407 -118.266538
# 146            South Robertson   0.000000    0.000000
# 147           Spaulding Square   0.000000    0.000000
# 148                Studio City  34.148399 -118.396188
# 149                    Sunland  34.266947 -118.302300
# 150            Sunset Junction  34.092649 -118.280795
# 151                 Sun Valley  34.220423 -118.387895
# 152                     Sylmar  34.307625 -118.449215
# 153                    Tarzana  34.171444 -118.542979
# 154            Terminal Island  33.745106 -118.263022
# 155                  Thai Town  34.101853 -118.304862
# 156                Toluca Lake  34.152169 -118.357142
# 157               Toy District  34.047048 -118.245510
# 158                    Tujunga  34.252225 -118.288410
# 159           University Hills  34.066649 -118.177440
# 160            University Park  34.027449 -118.283949
# 161            University Park  34.027449 -118.283949
# 162                Valley Glen  34.182638 -118.413867
# 163             Valley Village  34.163715 -118.396576
# 164                   Van Nuys  34.186619 -118.448667
# 165                     Venice  33.995044 -118.466887
# 166             Vermont Knolls  33.966819 -118.291670
# 167            Vermont-Slauson  33.983691 -118.291542
# 168             Vermont Square  34.001945 -118.300213
# 169              Vermont Vista  33.941947 -118.285814
# 170             Victor Heights  34.065381 -118.250621
# 171              Victoria Park  34.046689 -118.330773
# 172              Village Green  34.019871 -118.360664
# 173         Warehouse District  14.623036  121.042219
# 174              Warner Center  34.181146 -118.597442
# 175                      Watts  33.940567 -118.242848
# 176                 West Adams  34.029436 -118.352483
# 177                Westchester  33.954098 -118.400047
# 178                   Westdale  34.030389 -118.432012
# 179            Western Heights  32.534063  -96.851860
# 180                 West Hills  34.203232 -118.645476
# 181                   Westlake  34.062923 -118.272820
# 182           West Los Angeles  34.046399 -118.448135
# 183           Westside Village   0.000000    0.000000
# 184                   Westwood  34.066895 -118.439945
# 185           Westwood Village  34.059454 -118.444246
# 186            Whitley Heights  34.107379 -118.333629
# 187         Wholesale District  34.036575 -118.235434
# 188                 Wilmington  33.780016 -118.262509
# 189            Wilshire Center  34.061515 -118.432771
# 190             Windsor Square  34.072593 -118.320810
# 191                   Winnetka  34.205883 -118.570934
# 192             Woodland Hills  34.168436 -118.605838
# 193             Yucca Corridor   0.000000    0.000000

# %% [markdown]
# Deleting neighbourhoods with missing (zero) values and obvious geocoding errors: -

# %%
nhoods['Latitude']=nhoods['Latitude'].astype(float)
nhoods['Longitude']=nhoods['Longitude'].astype(float)

nhoods=nhoods[(nhoods.Latitude>33.5) & (nhoods.Latitude<34.4) & (nhoods.Longitude<-118)] 
nhoods.reset_index(inplace=True,drop=True)

# %% [markdown]
# Complete neighbourhood data frame: -

# %%
nhoods
# Out:
#                  Neighbourhood   Latitude   Longitude
# 0             Angelino Heights  34.070289 -118.254796
# 1                 Angeles Mesa  33.991402 -118.319520
# 2                       Arleta  34.241327 -118.432205
# 3            Arlington Heights  34.043494 -118.321374
# 4                Arts District  34.041239 -118.234450
# 5              Atwater Village  34.118698 -118.262392
# 6                Baldwin Hills  34.010989 -118.337071
# 7              Baldwin Village  34.019456 -118.345910
# 8             Beachwood Canyon  34.122292 -118.321384
# 9                      Bel Air  34.098883 -118.459881
# 10             Benedict Canyon  34.044770 -118.400022
# 11               Beverly Crest  34.116770 -118.432261
# 12                Beverly Glen  34.107785 -118.445636
# 13               Beverly Grove  34.076034 -118.369972
# 14   Beverly Hills Post Office  34.069650 -118.396306
# 15                Beverly Park  34.063769 -118.264690
# 16                 Beverlywood  34.046633 -118.395038
# 17               Boyle Heights  34.043689 -118.209768
# 18                   Brentwood  34.052140 -118.474070
# 19         Broadway-Manchester  33.941015 -118.274404
# 20                 Bunker Hill  34.055066 -118.251223
# 21               Cahuenga Pass  34.096867 -118.329508
# 22                 Canoga Park  34.201078 -118.597826
# 23           Canterbury Knolls  33.842760 -118.129731
# 24                     Carthay  34.061121 -118.367300
# 25             Central-Alameda  34.004015 -118.247784
# 26                Central City  34.053691 -118.242767
# 27                Century City  34.057426 -118.414727
# 28                  Chatsworth  34.259571 -118.602325
# 29         Chesterfield Square  33.983474 -118.313651
# 30               Cheviot Hills  34.040588 -118.409887
# 31                   Chinatown  34.063840 -118.235868
# 32                Civic Center  34.057561 -118.246810
# 33                    Crenshaw  33.925212 -118.326530
# 34             Crestwood Hills  34.076675 -118.488970
# 35                Cypress Park  34.092232 -118.224518
# 36                     Del Rey  33.989653 -118.424344
# 37                    Downtown  34.042849 -118.247673
# 38                  Eagle Rock  34.136688 -118.207680
# 39              East Hollywood  34.090428 -118.296625
# 40            East Los Angeles  34.023902 -118.172016
# 41                   Echo Park  34.077982 -118.256782
# 42                    Edendale  34.107516 -118.265949
# 43                   El Sereno  34.081121 -118.177849
# 44             Elysian Heights  34.099548 -118.244715
# 45                Elysian Park  34.077434 -118.238620
# 46              Elysian Valley  34.095913 -118.242033
# 47                      Encino  34.159132 -118.501617
# 48             Exposition Park  34.013654 -118.287211
# 49                     Fairfax  34.079155 -118.352284
# 50            Fashion District  34.036622 -118.259069
# 51          Financial District  34.050248 -118.255775
# 52                    Florence  33.974159 -118.243286
# 53             Flower District  34.040964 -118.249397
# 54                 Gallery Row  34.046687 -118.249490
# 55                    Garvanza  34.119578 -118.180626
# 56               Glassell Park  34.116120 -118.228963
# 57               Gramercy Park  33.951194 -118.309327
# 58               Granada Hills  34.266156 -118.517434
# 59               Green Meadows  33.940988 -118.262997
# 60               Griffith Park  34.134427 -118.305092
# 61                Hancock Park  34.073678 -118.335055
# 62                 Harbor City  33.797282 -118.300472
# 63              Harbor Gateway  33.854225 -118.299220
# 64             Harvard Heights  34.047111 -118.305483
# 65                Harvard Park  33.983947 -118.304623
# 66                      Hermon  34.107314 -118.185251
# 67               Highland Park  34.109947 -118.196983
# 68               Historic Core  34.045962 -118.251874
# 69                   Hollywood  34.098003 -118.329523
# 70             Hollywood Hills  34.131179 -118.335547
# 71                   Hyde Park  33.985402 -118.330861
# 72              Jefferson Park  34.029617 -118.322460
# 73            Jewelry District  34.046206 -118.254167
# 74                   Koreatown  34.061734 -118.305373
# 75                      Ladera  33.994179 -118.375354
# 76                 Lake Balboa  34.181166 -118.495236
# 77           Lake View Terrace  34.276391 -118.361191
# 78                   Larchmont  34.079837 -118.317870
# 79               Laurel Canyon  34.168465 -118.396296
# 80                Leimert Park  34.007702 -118.332063
# 81             Lincoln Heights  34.070929 -118.209890
# 82              Little Armenia  34.098172 -118.304497
# 83                Little Tokyo  34.048217 -118.241181
# 84                   Los Feliz  34.107656 -118.287506
# 85           Manchester Square  33.966374 -118.313378
# 86           Mandeville Canyon  34.061039 -118.494980
# 87            Marina Peninsula  33.748713 -118.122711
# 88                   Mar Vista  34.003760 -118.439164
# 89                    Mid-City  34.041527 -118.360370
# 90                Mid-Wilshire  34.056862 -118.345803
# 91               Mission Hills  34.257225 -118.467028
# 92           Montecito Heights  34.089540 -118.194279
# 93              Monterey Hills  34.104176 -118.164238
# 94            Mount Washington  34.098840 -118.221107
# 95              Nichols Canyon  34.109307 -118.361017
# 96                 North Hills  34.242958 -118.485408
# 97             North Hollywood  34.172904 -118.374037
# 98                  Northridge  34.234561 -118.536932
# 99           Pacific Palisades  34.048064 -118.526471
# 100                    Pacoima  34.262502 -118.427027
# 101                      Palms  34.024733 -118.411615
# 102              Panorama City  34.224290 -118.445374
# 103               Park La Brea  34.067402 -118.355236
# 104                 Pico-Union  34.046567 -118.287894
# 105              Playa del Rey  33.955083 -118.436750
# 106                Playa Vista  33.975957 -118.418182
# 107               Porter Ranch  34.281816 -118.561271
# 108                Rancho Park  34.034446 -118.425263
# 109                     Reseda  34.200078 -118.536988
# 110              Rustic Canyon  34.077997 -118.519128
# 111                  San Pedro  33.735852 -118.292293
# 112                   Sawtelle  34.036111 -118.450356
# 113               Shadow Hills  34.261947 -118.351746
# 114               Sherman Oaks  34.150872 -118.448987
# 115                Silver Lake  34.089652 -118.269374
# 116                   Skid Row  34.044057 -118.243851
# 117              Solano Canyon  34.081887 -118.234983
# 118                 South Park  34.040407 -118.266538
# 119                Studio City  34.148399 -118.396188
# 120                    Sunland  34.266947 -118.302300
# 121            Sunset Junction  34.092649 -118.280795
# 122                 Sun Valley  34.220423 -118.387895
# 123                     Sylmar  34.307625 -118.449215
# 124                    Tarzana  34.171444 -118.542979
# 125            Terminal Island  33.745106 -118.263022
# 126                  Thai Town  34.101853 -118.304862
# 127                Toluca Lake  34.152169 -118.357142
# 128               Toy District  34.047048 -118.245510
# 129                    Tujunga  34.252225 -118.288410
# 130           University Hills  34.066649 -118.177440
# 131            University Park  34.027449 -118.283949
# 132            University Park  34.027449 -118.283949
# 133                Valley Glen  34.182638 -118.413867
# 134             Valley Village  34.163715 -118.396576
# 135                   Van Nuys  34.186619 -118.448667
# 136                     Venice  33.995044 -118.466887
# 137             Vermont Knolls  33.966819 -118.291670
# 138            Vermont-Slauson  33.983691 -118.291542
# 139             Vermont Square  34.001945 -118.300213
# 140              Vermont Vista  33.941947 -118.285814
# 141             Victor Heights  34.065381 -118.250621
# 142              Victoria Park  34.046689 -118.330773
# 143              Village Green  34.019871 -118.360664
# 144              Warner Center  34.181146 -118.597442
# 145                      Watts  33.940567 -118.242848
# 146                 West Adams  34.029436 -118.352483
# 147                Westchester  33.954098 -118.400047
# 148                   Westdale  34.030389 -118.432012
# 149                 West Hills  34.203232 -118.645476
# 150                   Westlake  34.062923 -118.272820
# 151           West Los Angeles  34.046399 -118.448135
# 152                   Westwood  34.066895 -118.439945
# 153           Westwood Village  34.059454 -118.444246
# 154            Whitley Heights  34.107379 -118.333629
# 155         Wholesale District  34.036575 -118.235434
# 156                 Wilmington  33.780016 -118.262509
# 157            Wilshire Center  34.061515 -118.432771
# 158             Windsor Square  34.072593 -118.320810
# 159                   Winnetka  34.205883 -118.570934
# 160             Woodland Hills  34.168436 -118.605838

# %% [markdown]
# ### LA Neighbourhood Map <a name="lamap"></a>

# %% [markdown]
# Obtaining the coordinates of the center of LA: -

# %%
address = 'Los Angeles, USA'

geolocator = Nominatim(user_agent="la_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of {} are {}, {}.'.format(address,latitude, longitude))
# Out:
# The geograpical coordinates of Los Angeles, USA are 34.0536909, -118.2427666.

# %% [markdown]
# Creating a map of LA with neighbourhoods superimposed on top: -

# %%
# create map of LA using latitude and longitude values
map_la = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, neighbourhood in zip(nhoods['Latitude'], nhoods['Longitude'], nhoods['Neighbourhood']):
    label = '{}'.format(neighbourhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3199cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_la)  
    
map_la
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Defining Foursquare Credentials and Version   <a name="foursquare"></a>

# %%
CLIENT_ID = 'BPAX1A44J1YTPYCUOCZXBY41JTWTHB3H2M2ISKZTYCO5LQMA' # Foursquare ID
CLIENT_SECRET = 'LSLUNFQNMUBH4KXC1S1O41RTPWP2J41IYQFMO44NU5GTJSER' # Foursquare Secret
VERSION = '20200605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET: ' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BPAX1A44J1YTPYCUOCZXBY41JTWTHB3H2M2ISKZTYCO5LQMA
# CLIENT_SECRET: LSLUNFQNMUBH4KXC1S1O41RTPWP2J41IYQFMO44NU5GTJSER

# %% [markdown]
# ### Exploring the first Neighbourhood <a name="first"></a>

# %%
neighbourhood_latitude = nhoods.loc[0, 'Latitude'] # neighbourhood latitude value
neighbourhood_longitude = nhoods.loc[0, 'Longitude'] # neighbourhood longitude value

neighbourhood_name = nhoods.loc[0, 'Neighbourhood'] # neighbourhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighbourhood_name, 
                                                               neighbourhood_latitude, 
                                                               neighbourhood_longitude))
# Out:
# Latitude and longitude values of Angelino Heights are 34.0702889, -118.2547965.

# %%
LIMIT = 500 # Maximum is 100
cities = ['Los Angeles']
results = {}
for city in cities:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&limit={}&categoryId={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        city,
        LIMIT,
        "4bf58dd8d48988d1d3941735") # Vegan resturants CATEGORY ID
    url

# %%
results[city] = requests.get(url).json()
results
# Out:
# {'Los Angeles': {'meta': {'code': 200,
#    'requestId': '5edf4f3e0cc1fd001b9d1ddc'},
#   'response': {'suggestedFilters': {'header': 'Tap to show:',
#     'filters': [{'name': '$-$$$$', 'key': 'price'}]},
#    'geocode': {'what': '',
#     'where': 'los angeles',
#     'center': {'lat': 34.05223, 'lng': -118.24368},
#     'displayString': 'Los Angeles, CA, United States',
#     'cc': 'US',
#     'geometry': {'bounds': {'ne': {'lat': 34.337306, 'lng': -118.155289},
#       'sw': {'lat': 33.703652, 'lng': -118.668176}}},
#     'slug': 'los-angeles-california',
#     'longId': '72057594043296297'},
#    'headerLocation': 'Los Angeles',
#    'headerFullLocation': 'Los Angeles',
#    'headerLocationGranularity': 'city',
#    'query': 'vegetarian vegan',
#    'totalResults': 245,
#    'suggestedBounds': {'ne': {'lat': 34.26382807081869,
#      'lng': -118.17005466082605},
#     'sw': {'lat': 33.94520505227639, 'lng': -118.6262885892188}},
#    'groups': [{'type': 'Recommended Places',
#      'name': 'recommended',
#      'items': [{'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4d6c1f8208145941e8e23c7b',
#         'name': 'Café Gratitude',
#         'location': {'address': '639 N Larchmont Blvd',
#          'crossStreet': 'at Melrose Ave',
#          'lat': 34.08293949353896,
#          'lng': -118.3238069457162,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.08293949353896,
#            'lng': -118.3238069457162}],
#          'postalCode': '90004',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['639 N Larchmont Blvd (at Melrose Ave)',
#           'Los Angeles, CA 90004',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4d6c1f8208145941e8e23c7b-0'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b8c669ef964a520e2ce32e3',
#         'name': 'SunCafe Organic',
#         'location': {'address': '10820 Ventura Blvd',
#          'crossStreet': 'at Fruitland Dr',
#          'lat': 34.13860151329137,
#          'lng': -118.36649239027683,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.13860151329137,
#            'lng': -118.36649239027683},
#           {'label': 'entrance', 'lat': 34.13859, 'lng': -118.366497}],
#          'postalCode': '91604',
#          'cc': 'US',
#          'city': 'Studio City',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['10820 Ventura Blvd (at Fruitland Dr)',
#           'Studio City, CA 91604',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '414269',
#          'url': 'https://www.grubhub.com/restaurant/suncafe-organic-10820-ventura-blvd-studio-city/414269?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=414269',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '92258076'}},
#        'referralId': 'e-0-4b8c669ef964a520e2ce32e3-1'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '551b4715498e659a91e38928',
#         'name': 'Vegetable',
#         'location': {'address': '3711 Cahuenga',
#          'crossStreet': 'Regal',
#          'lat': 34.1350658860204,
#          'lng': -118.36155542095304,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.1350658860204,
#            'lng': -118.36155542095304}],
#          'postalCode': '91604',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['3711 Cahuenga (Regal)',
#           'Los Angeles, CA 91604',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-551b4715498e659a91e38928-2'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4dd535a6c65be32e5f967265',
#         'name': 'Veggie Grill',
#         'location': {'address': '110 S Fairfax Ave',
#          'crossStreet': 'at 3rd St',
#          'lat': 34.0736849,
#          'lng': -118.3608384,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.0736849,
#            'lng': -118.3608384}],
#          'postalCode': '90036',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['110 S Fairfax Ave (at 3rd St)',
#           'Los Angeles, CA 90036',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '304258',
#          'url': 'https://www.grubhub.com/restaurant/veggie-grill-110-s-fairfax-ave-los-angeles/304258?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=304258',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '491516122'}},
#        'referralId': 'e-0-4dd535a6c65be32e5f967265-3'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4a41af9cf964a52089a51fe3',
#         'name': 'Native Foods',
#         'location': {'address': '1114 Gayley Ave',
#          'crossStreet': 'at Kinross Ave',
#          'lat': 34.059988,
#          'lng': -118.445983,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.059988,
#            'lng': -118.445983}],
#          'postalCode': '90024',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['1114 Gayley Ave (at Kinross Ave)',
#           'Los Angeles, CA 90024',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '312054',
#          'url': 'https://www.grubhub.com/restaurant/native-foods-1114-gayley-ave-westwood-village/312054?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=312054',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4a41af9cf964a52089a51fe3-4'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '574dd15a498e5d4280aa4b97',
#         'name': 'By Chloe',
#         'location': {'address': '2520 Glendale Blvd',
#          'lat': 34.1028766,
#          'lng': -118.2584507,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.1028766,
#            'lng': -118.2584507}],
#          'postalCode': '90039',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['2520 Glendale Blvd',
#           'Los Angeles, CA 90039',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '1017790',
#          'url': 'https://www.grubhub.com/restaurant/by-chloe-2520-glendale-blvd-los-angeles/1017790?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1017790',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-574dd15a498e5d4280aa4b97-5'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4a0a51d3f964a52099741fe3',
#         'name': 'Flore Vegan Restaurant',
#         'location': {'address': '3818 W Sunset Blvd',
#          'crossStreet': 'at Lucile Ave.',
#          'lat': 34.09134178161039,
#          'lng': -118.27938606579022,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.09134178161039,
#            'lng': -118.27938606579022},
#           {'label': 'entrance', 'lat': 34.091203, 'lng': -118.279391}],
#          'postalCode': '90026',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['3818 W Sunset Blvd (at Lucile Ave.)',
#           'Los Angeles, CA 90026',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4a0a51d3f964a52099741fe3-6'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '56674ce0498e53681084b32b',
#         'name': "The Butcher's Daughter",
#         'location': {'address': '1205 Abbot Kinney',
#          'lat': 33.99160767414249,
#          'lng': -118.46921844736259,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 33.99160767414249,
#            'lng': -118.46921844736259}],
#          'postalCode': '90291',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['1205 Abbot Kinney',
#           'Los Angeles, CA 90291',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '2016573',
#          'url': 'https://www.grubhub.com/restaurant/the-butchers-daughter-1205-abbot-kinney-blvd-los-angeles/2016573?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2016573',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-56674ce0498e53681084b32b-7'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4ff8a3d6e4b0f1c619297ae1',
#         'name': 'Café Gratitude',
#         'location': {'address': '512 Rose Ave',
#          'lat': 33.998152665858285,
#          'lng': -118.47381095450288,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 33.998152665858285,
#            'lng': -118.47381095450288},
#           {'label': 'entrance', 'lat': 33.998302, 'lng': -118.473317}],
#          'postalCode': '90291',
#          'cc': 'US',
#          'city': 'Venice',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['512 Rose Ave',
#           'Venice, CA 90291',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4ff8a3d6e4b0f1c619297ae1-8'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b6b7241f964a5205d092ce3',
#         'name': 'H.O.P.E. (Healthy Organic Positive Eating) (formerly Vegan Plate)',
#         'location': {'address': '11943 Ventura Blvd.',
#          'crossStreet': 'Laurel Canyon Blvd.',
#          'lat': 34.14359781230447,
#          'lng': -118.39194619120453,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.14359781230447,
#            'lng': -118.39194619120453}],
#          'postalCode': '91604',
#          'cc': 'US',
#          'city': 'Studio City',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['11943 Ventura Blvd. (Laurel Canyon Blvd.)',
#           'Studio City, CA 91604',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '298276',
#          'url': 'https://www.grubhub.com/restaurant/hope-healthy-organic-positive-eating-11943-ventura-blvd-studio-city/298276?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=298276',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b6b7241f964a5205d092ce3-9'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5228e77411d2096e343a78f9',
#         'name': 'Sage Organic Vegan Bistro',
#         'location': {'address': '4130 Sepulveda Blvd',
#          'crossStreet': 'at Washington Blvd',
#          'lat': 34.00640912972718,
#          'lng': -118.41218139178056,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.00640912972718,
#            'lng': -118.41218139178056}],
#          'postalCode': '90230',
#          'cc': 'US',
#          'neighborhood': 'West Los Angeles',
#          'city': 'Culver City',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['4130 Sepulveda Blvd (at Washington Blvd)',
#           'Culver City, CA 90230',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5228e77411d2096e343a78f9-10'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4d7060ae68276ea855578790',
#         'name': 'Sage Organic Vegan Bistro',
#         'location': {'address': '1700 W Sunset Blvd',
#          'crossStreet': 'at Logan St',
#          'lat': 34.07715025130554,
#          'lng': -118.25850979016774,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.07715025130554,
#            'lng': -118.25850979016774}],
#          'postalCode': '90026',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['1700 W Sunset Blvd (at Logan St)',
#           'Los Angeles, CA 90026',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '348824',
#          'url': 'https://www.grubhub.com/restaurant/sage-vegan-bistro-1700-w-sunset-blvd-los-angeles/348824?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=348824',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4d7060ae68276ea855578790-11'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b0ab0a0f964a5206c2623e3',
#         'name': 'Earth Bar',
#         'location': {'address': '8365 Santa Monica Blvd',
#          'crossStreet': 'Flores St',
#          'lat': 34.09080287785582,
#          'lng': -118.3718728865745,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.09080287785582,
#            'lng': -118.3718728865745}],
#          'postalCode': '90069',
#          'cc': 'US',
#          'city': 'West Hollywood',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['8365 Santa Monica Blvd (Flores St)',
#           'West Hollywood, CA 90069',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b0ab0a0f964a5206c2623e3-12'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5090279ce4b014dc9428ded9',
#         'name': 'Veggie Grill',
#         'location': {'address': '6374-A Sunset Boulevard',
#          'crossStreet': 'at Ivar Ave',
#          'lat': 34.09782440000001,
#          'lng': -118.3284406,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.09782440000001,
#            'lng': -118.3284406},
#           {'label': 'entrance', 'lat': 34.097853, 'lng': -118.328135}],
#          'postalCode': '90028',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['6374-A Sunset Boulevard (at Ivar Ave)',
#           'Hollywood, CA 90028',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '304253',
#          'url': 'https://www.grubhub.com/restaurant/veggie-grill-6374-sunset-blvd-los-angeles/304253?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=304253',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '490014371'}},
#        'referralId': 'e-0-5090279ce4b014dc9428ded9-13'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '515d02f9e4b001a17a74c71e',
#         'name': 'The Grain Cafe',
#         'location': {'address': '4222 W Pico Blvd',
#          'lat': 34.047713241983026,
#          'lng': -118.32760077493121,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.047713241983026,
#            'lng': -118.32760077493121},
#           {'label': 'entrance', 'lat': 34.047758, 'lng': -118.327553}],
#          'postalCode': '90019',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['4222 W Pico Blvd',
#           'Los Angeles, CA 90019',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '1528212',
#          'url': 'https://www.grubhub.com/restaurant/the-grain-cafe-4222-west-pico-boulevard-los-angeles/1528212?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1528212',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-515d02f9e4b001a17a74c71e-14'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4d0bcdc96c51a14389a6ac35',
#         'name': 'Veggie Grill',
#         'location': {'address': '2025 Wilshire Blvd',
#          'crossStreet': 'at 21st St',
#          'lat': 34.0321,
#          'lng': -118.48287,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.0321,
#            'lng': -118.48287},
#           {'label': 'entrance', 'lat': 34.031952, 'lng': -118.482731}],
#          'postalCode': '90403',
#          'cc': 'US',
#          'city': 'Santa Monica',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['2025 Wilshire Blvd (at 21st St)',
#           'Santa Monica, CA 90403',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '300629',
#          'url': 'https://www.grubhub.com/restaurant/veggie-grill-2025-wilshire-blvd-santa-monica/300629?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=300629',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '493764767'}},
#        'referralId': 'e-0-4d0bcdc96c51a14389a6ac35-15'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4aee35c4f964a52001d321e3',
#         'name': 'Vegan Glory',
#         'location': {'address': '8393 Beverly Blvd',
#          'lat': 34.07623651196047,
#          'lng': -118.3730298244673,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.07623651196047,
#            'lng': -118.3730298244673}],
#          'postalCode': '90048',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['8393 Beverly Blvd',
#           'Los Angeles, CA 90048',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '70599',
#          'url': 'https://www.grubhub.com/restaurant/vegan-glory-8393-beverly-blvd-los-angeles/70599?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=70599',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4aee35c4f964a52001d321e3-16'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '49c141eaf964a52095551fe3',
#         'name': 'M Café',
#         'location': {'address': '7119 Melrose Ave',
#          'crossStreet': 'La Brea',
#          'lat': 34.08359702037952,
#          'lng': -118.34491534158711,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.08359702037952,
#            'lng': -118.34491534158711},
#           {'label': 'entrance', 'lat': 34.083626, 'lng': -118.344899}],
#          'postalCode': '90046',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['7119 Melrose Ave (La Brea)',
#           'Los Angeles, CA 90046',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-49c141eaf964a52095551fe3-17'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5648c6c6498e37c29c43847d',
#         'name': 'Little Pine Restaurant',
#         'location': {'address': '2870 Rowena Ave',
#          'lat': 34.10781019565671,
#          'lng': -118.26679692121121,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.10781019565671,
#            'lng': -118.26679692121121},
#           {'label': 'entrance', 'lat': 34.107837, 'lng': -118.266788}],
#          'postalCode': '90039',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['2870 Rowena Ave',
#           'Los Angeles, CA 90039',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5648c6c6498e37c29c43847d-18'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5518423c498edbf62812dbe4',
#         'name': 'Cafe Gratitude',
#         'location': {'address': '300 S Santa Fe Ave Ste A',
#          'crossStreet': 'at E 3rd St',
#          'lat': 34.04562851412795,
#          'lng': -118.23255871190399,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.04562851412795,
#            'lng': -118.23255871190399}],
#          'postalCode': '90013',
#          'cc': 'US',
#          'neighborhood': 'Arts District',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['300 S Santa Fe Ave Ste A (at E 3rd St)',
#           'Los Angeles, CA 90013',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5518423c498edbf62812dbe4-19'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5143f55ee4b027a9f6d94e3a',
#         'name': 'Crossroads Kitchen',
#         'location': {'address': '8284 Melrose Ave',
#          'lat': 34.08355377036199,
#          'lng': -118.37021756510343,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.08355377036199,
#            'lng': -118.37021756510343},
#           {'label': 'entrance', 'lat': 34.083566, 'lng': -118.370118}],
#          'postalCode': '90046',
#          'cc': 'US',
#          'neighborhood': 'Mid-City West',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['8284 Melrose Ave',
#           'Los Angeles, CA 90046',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '1294388',
#          'url': 'https://www.grubhub.com/restaurant/crossroads-kitchen-8284-melrose-ave-los-angeles/1294388?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1294388',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5143f55ee4b027a9f6d94e3a-20'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '52362b2011d2aea46f5bc367',
#         'name': 'My Vegan Gold Edition',
#         'location': {'address': '4319 W. Sunset Blvd',
#          'crossStreet': 'Fountain',
#          'lat': 34.095183,
#          'lng': -118.283163,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.095183,
#            'lng': -118.283163}],
#          'postalCode': '90029',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['4319 W. Sunset Blvd (Fountain)',
#           'Los Angeles, CA 90029',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '283889',
#          'url': 'https://www.grubhub.com/restaurant/my-vegan-gold-4319-w-sunset-blvd-los-angeles/283889?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=283889',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-52362b2011d2aea46f5bc367-21'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4ab6a678f964a5206d7820e3',
#         'name': 'Veggie Grill',
#         'location': {'address': '8000 Sunset Boulevard',
#          'crossStreet': 'at N Crescent Heights Blvd',
#          'lat': 34.09760430000001,
#          'lng': -118.365233,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.09760430000001,
#            'lng': -118.365233}],
#          'postalCode': '90046',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['8000 Sunset Boulevard (at N Crescent Heights Blvd)',
#           'Los Angeles, CA 90046',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '304257',
#          'url': 'https://www.grubhub.com/restaurant/veggie-grill-8000-w-sunset-blvd-los-angeles/304257?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=304257',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '494262119'}},
#        'referralId': 'e-0-4ab6a678f964a5206d7820e3-22'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '49ff23c3f964a520de6f1fe3',
#         'name': "Hugo's Restaurant",
#         'location': {'address': '12851 Riverside Dr',
#          'crossStreet': 'at Coldwater Canyon Ave',
#          'lat': 34.15769542902923,
#          'lng': -118.41329939455598,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.15769542902923,
#            'lng': -118.41329939455598}],
#          'postalCode': '91607',
#          'cc': 'US',
#          'city': 'Studio City',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['12851 Riverside Dr (at Coldwater Canyon Ave)',
#           'Studio City, CA 91607',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '1600920',
#          'url': 'https://www.grubhub.com/restaurant/hugos-restaurant-12851-riverside-drive-los-angeles/1600920?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1600920',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '91923699'}},
#        'referralId': 'e-0-49ff23c3f964a520de6f1fe3-23'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b41528af964a52059c525e3',
#         'name': 'LA Vegan',
#         'location': {'address': '4507 S Centinela Ave',
#          'crossStreet': 'Short Ave',
#          'lat': 33.99273834024122,
#          'lng': -118.42323649325132,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 33.99273834024122,
#            'lng': -118.42323649325132}],
#          'postalCode': '90066',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['4507 S Centinela Ave (Short Ave)',
#           'Los Angeles, CA 90066',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '310779',
#          'url': 'https://www.grubhub.com/restaurant/la-vegan-4507-s-centinela-ave-los-angeles/310779?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=310779',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b41528af964a52059c525e3-24'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5705a4e3498ea0a84f29d7f6',
#         'name': 'Tocaya Organica',
#         'location': {'address': '1715 Pacific Ave',
#          'lat': 33.986639,
#          'lng': -118.471664,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 33.986639,
#            'lng': -118.471664}],
#          'postalCode': '90291',
#          'cc': 'US',
#          'city': 'Venice',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['1715 Pacific Ave',
#           'Venice, CA 90291',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5705a4e3498ea0a84f29d7f6-25'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5367b187498e4b8c5c901c9d',
#         'name': 'The Harvest Bar Superfood Cafe',
#         'location': {'address': '15030 Ventura Blvd',
#          'lat': 34.152662538918804,
#          'lng': -118.46060657615094,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.152662538918804,
#            'lng': -118.46060657615094}],
#          'postalCode': '91403',
#          'cc': 'US',
#          'city': 'Sherman Oaks',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['15030 Ventura Blvd',
#           'Sherman Oaks, CA 91403',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '2016672',
#          'url': 'https://www.grubhub.com/restaurant/the-harvest-bar-15030-ventura-blvd-los-angeles/2016672?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2016672',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5367b187498e4b8c5c901c9d-26'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '59fd2ca77247505ab32d39ac',
#         'name': 'sweetgreen',
#         'location': {'address': '4700 Admiralty Way',
#          'lat': 33.97990881678697,
#          'lng': -118.43903303146362,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 33.97990881678697,
#            'lng': -118.43903303146362}],
#          'postalCode': '90292',
#          'cc': 'US',
#          'city': 'Marina del Rey',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['4700 Admiralty Way',
#           'Marina del Rey, CA 90292',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '917642',
#          'url': 'https://www.grubhub.com/restaurant/sweetgreen-4700-admiralty-way-marina-del-rey/917642?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=917642',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-59fd2ca77247505ab32d39ac-27'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5a63bfa5d4cc9805fbd93763',
#         'name': 'Modern Times Beer: The Dankness Dojo',
#         'location': {'address': '832 S Olive St',
#          'crossStreet': 'btwn 8th & 9th St',
#          'lat': 34.04413306256049,
#          'lng': -118.25759999938829,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.04413306256049,
#            'lng': -118.25759999938829}],
#          'postalCode': '90014',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['832 S Olive St (btwn 8th & 9th St)',
#           'Los Angeles, CA 90014',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5a63bfa5d4cc9805fbd93763-28'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4a105a66f964a520a8761fe3',
#         'name': "Hugo's Restaurant",
#         'location': {'address': '8401 Santa Monica Blvd',
#          'crossStreet': 'at Kings Rd',
#          'lat': 34.09074120878316,
#          'lng': -118.37287868778176,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.09074120878316,
#            'lng': -118.37287868778176},
#           {'label': 'entrance', 'lat': 34.090778, 'lng': -118.37313}],
#          'postalCode': '90069',
#          'cc': 'US',
#          'city': 'West Hollywood',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['8401 Santa Monica Blvd (at Kings Rd)',
#           'West Hollywood, CA 90069',
#           'United States']},
# ...
#          'crossStreet': 'at 26th St',
#          'lat': 34.048474715244346,
#          'lng': -118.49039607943024,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.048474715244346,
#            'lng': -118.49039607943024},
#           {'label': 'entrance', 'lat': 34.048477, 'lng': -118.490501}],
#          'postalCode': '90049',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['13016 San Vicente Blvd (at 26th St)',
#           'Los Angeles, CA 90049',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '2111981',
#          'url': 'https://www.grubhub.com/restaurant/a-votre-sante-13016-san-vicente-blvd-los-angeles/2111981?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2111981',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b31295cf964a520790125e3-89'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '49fa6031f964a520f26d1fe3',
#         'name': 'Green Leaves Vegan',
#         'location': {'address': '1769 Hillhurst Ave',
#          'crossStreet': 'at Melbourne Ave',
#          'lat': 34.103329670116466,
#          'lng': -118.28756396594075,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.103329670116466,
#            'lng': -118.28756396594075},
#           {'label': 'entrance', 'lat': 34.103312, 'lng': -118.287543}],
#          'postalCode': '90027',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['1769 Hillhurst Ave (at Melbourne Ave)',
#           'Los Angeles, CA 90027',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '280256',
#          'url': 'https://www.grubhub.com/restaurant/green-leaves-vegan-1769-hillhurst-ave-los-angeles/280256?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=280256',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-49fa6031f964a520f26d1fe3-90'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5430584e498ed2ae57fdd06e',
#         'name': 'Vromage Artisan Cheese',
#         'location': {'address': '7988 W Sunset Blvd',
#          'lat': 34.097626,
#          'lng': -118.364182,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.097626,
#            'lng': -118.364182}],
#          'postalCode': '90046',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['7988 W Sunset Blvd',
#           'Los Angeles, CA 90046',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5430584e498ed2ae57fdd06e-91'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4f333925e4b0a74999e535ed',
#         'name': 'Vestation',
#         'location': {'address': '14435 Ventura Blvd',
#          'crossStreet': 'at Van Nuys Blvd',
#          'lat': 34.1514787633764,
#          'lng': -118.44743692380221,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.1514787633764,
#            'lng': -118.44743692380221},
#           {'label': 'entrance', 'lat': 34.151477, 'lng': -118.447896}],
#          'postalCode': '91423',
#          'cc': 'US',
#          'city': 'Sherman Oaks',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['14435 Ventura Blvd (at Van Nuys Blvd)',
#           'Sherman Oaks, CA 91423',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '141556',
#          'url': 'https://www.grubhub.com/restaurant/vestation-14435-ventura-blvd-sherman-oaks/141556?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=141556',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4f333925e4b0a74999e535ed-92'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b8a057af964a520055c32e3',
#         'name': 'Mandoline Grill Truck',
#         'location': {'crossStreet': 'Greater LA Metro Area',
#          'lat': 34.10177738338736,
#          'lng': -118.34529593874898,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.10177738338736,
#            'lng': -118.34529593874898}],
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['Greater LA Metro Area',
#           'Los Angeles, CA',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b8a057af964a520055c32e3-93'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '595179669b04731d548bc218',
#         'name': 'Tocaya - Playa Vista',
#         'location': {'address': '12150 Millennium #101',
#          'crossStreet': 'S. Campus Center',
#          'lat': 33.9791213,
#          'lng': -118.4070751,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 33.9791213,
#            'lng': -118.4070751}],
#          'postalCode': '90094',
#          'cc': 'US',
#          'neighborhood': 'Playa Vista, CA',
#          'city': 'Playa Vista',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['12150 Millennium #101 (S. Campus Center)',
#           'Playa Vista, CA 90094',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-595179669b04731d548bc218-94'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '43bd0e5ef964a520002d1fe3',
#         'name': 'Groundwork Coffee Co.',
#         'location': {'address': '1501 N Cahuenga Blvd',
#          'crossStreet': 'at Sunset Blvd',
#          'lat': 34.0980944512876,
#          'lng': -118.32962288916437,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.0980944512876,
#            'lng': -118.32962288916437},
#           {'label': 'entrance', 'lat': 34.098178, 'lng': -118.329638}],
#          'postalCode': '90028',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['1501 N Cahuenga Blvd (at Sunset Blvd)',
#           'Los Angeles, CA 90028',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '96151980'}},
#        'referralId': 'e-0-43bd0e5ef964a520002d1fe3-95'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '5b6d322b419a9e0039484b94',
#         'name': 'Monty’s Good Burger',
#         'location': {'address': '516 S Western Ave',
#          'lat': 34.06479708820793,
#          'lng': -118.30903426295419,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.06479708820793,
#            'lng': -118.30903426295419}],
#          'postalCode': '90020',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['516 S Western Ave',
#           'Los Angeles, CA 90020',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-5b6d322b419a9e0039484b94-96'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '49ea205ef964a52027661fe3',
#         'name': "Hugo's Tacos",
#         'location': {'address': '4749 Coldwater Canyon Ave',
#          'crossStreet': 'at Riverside Dr.',
#          'lat': 34.15728266805428,
#          'lng': -118.41388747976333,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.15728266805428,
#            'lng': -118.41388747976333}],
#          'postalCode': '91604',
#          'cc': 'US',
#          'city': 'Studio City',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['4749 Coldwater Canyon Ave (at Riverside Dr.)',
#           'Studio City, CA 91604',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-49ea205ef964a52027661fe3-97'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4a807da3f964a52075f51fe3',
#         'name': "Govinda's",
#         'location': {'address': '3764 Watseka Ave',
#          'crossStreet': 'at Venice',
#          'lat': 34.02510684280419,
#          'lng': -118.39732513914875,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.02510684280419,
#            'lng': -118.39732513914875}],
#          'postalCode': '90034',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['3764 Watseka Ave (at Venice)',
#           'Los Angeles, CA 90034',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4a807da3f964a52075f51fe3-98'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4a5a8081f964a52072ba1fe3',
#         'name': 'Cruzer Pizza',
#         'location': {'address': '5051 Hollywood Blvd',
#          'crossStreet': 'at Hillhurst Ave',
#          'lat': 34.1020238,
#          'lng': -118.2996004,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 34.1020238,
#            'lng': -118.2996004},
#           {'label': 'entrance', 'lat': 34.101904, 'lng': -118.299594}],
#          'postalCode': '90027',
#          'cc': 'US',
#          'city': 'Los Angeles',
#          'state': 'CA',
#          'country': 'United States',
#          'formattedAddress': ['5051 Hollywood Blvd (at Hillhurst Ave)',
#           'Los Angeles, CA 90027',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1d3941735',
#           'name': 'Vegetarian / Vegan Restaurant',
#           'pluralName': 'Vegetarian / Vegan Restaurants',
#           'shortName': 'Vegetarian / Vegan',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '346794',
#          'url': 'https://www.grubhub.com/restaurant/cruzer-pizza-100-vegan-4449-prospect-ave-los-angeles/346794?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=346794',
#          'provider': {'name': 'grubhub',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_grubhub_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4a5a8081f964a52072ba1fe3-99'}]}]}}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Nearby venues of the first neighbourhood: -

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-561c05f0fdd1> in <module>
# ----> 1 venues = results['response']['groups'][0]['items']
#       2
#       3 nearby_venues = json_normalize(venues) # flatten JSON
#       4
#       5 # filter columns
#
# KeyError: 'response'

# %% [markdown]
# ### Exploring all Neighbourhoods  <a name="all"></a>

# %% [markdown]
# Function to get the nearby venues of all neighbourhoods and load the data into a data frame: -

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
la_venues = getNearbyVenues(names=nhoods['Neighbourhood'],
                                   latitudes=nhoods['Latitude'],
                                   longitudes=nhoods['Longitude']
                                  )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-dc7b3ccb9150> in <module>
#       1 la_venues = getNearbyVenues(names=nhoods['Neighbourhood'],
#       2                                    latitudes=nhoods['Latitude'],
# ----> 3                                    longitudes=nhoods['Longitude']
#       4                                   )
#
# <ipython-input-69-4839e571128f> in getNearbyVenues(names, latitudes, longitudes, radius)
#      16
#      17         # make the GET request
# ---> 18         results = requests.get(url).json()["response"]['groups'][0]['items']
#      19
#      20         # return only relevant information for each nearby venue
#
# KeyError: 'groups'

# %% [markdown]
# Data frame of all venues: -

# %%
print(la_venues.shape)
la_venues.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-bb87eacc2e7b> in <module>
# ----> 1 print(la_venues.shape)
#       2 la_venues.head()
#
# NameError: name 'la_venues' is not defined

# %%
la_venues_count=la_venues.groupby('Neighbourhood').count()
la_venues_count.drop(la_venues_count.columns[[0,1,3,4,5]], axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-ed442faf7f7a> in <module>
# ----> 1 la_venues_count=la_venues.groupby('Neighbourhood').count()
#       2 la_venues_count.drop(la_venues_count.columns[[0,1,3,4,5]], axis=1,inplace=True)
#
# NameError: name 'la_venues' is not defined

# %%
la_venues_count.reset_index(inplace=True)

# %% [markdown]
# It makes sense to set up a restaurant in one of the more popular neighbourhoods so that the restaurant attracts the attention of a lot more people.
#
# Therefore, a list of all the popular neighbourhoods i.e. the neighbourhoods with 10 or more venues is obtained: -

# %%
pop_neigh=la_venues_count[(la_venues_count.Venue>=10)]
pop_neigh.reset_index(drop=True,inplace=True)
pop_neigh

# %% [markdown]
# Updating the venues data frame to include only the venues which are in popular neighbourhoods: -

# %%
pop_list=pop_neigh['Neighbourhood'].values.tolist()

for i in range(0,len(la_venues)):

    if la_venues.iloc[i,0] not in pop_list:
        la_venues.iloc[i,0]='TO DROP'

la_venues=la_venues[la_venues.Neighbourhood!='TO DROP']
la_venues.reset_index(drop=True,inplace=True)

# %%
la_venues

# %%
print('There are {} uniques categories.'.format(len(la_venues['Venue Category'].unique())))

# %% [markdown]
# ### Analyzing each Neighbourhood  <a name="analyze"></a>

# %%
# one hot encoding
la_onehot = pd.get_dummies(la_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighbourhood column back to data frame
la_onehot['Neighbourhood'] = la_venues['Neighbourhood'] 

# move neighbourhood column to the first column
fixed_columns = [la_onehot.columns[-1]] + list(la_onehot.columns[:-1])
la_onehot = la_onehot[fixed_columns]

la_onehot.head()

# %% [markdown]
# Grouping rows by neighbourhood by taking the mean of the frequency of occurrence of each category: -

# %%
la_grouped = la_onehot.groupby('Neighbourhood').mean().reset_index()
la_grouped

# %% [markdown]
# Printing each neighbourhood along with the top 5 most common venues: -

# %%
num_top_venues = 5

for hood in la_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = la_grouped[la_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['VENUE','FREQ']
    temp = temp.iloc[1:]
    temp['FREQ'] = temp['FREQ'].astype(float)
    temp = temp.round({'FREQ': 2})
    print(temp.sort_values('FREQ', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

# %% [markdown]
# Creating a new data frame and displaying the top 10 venues for each neighbourhood: -

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new data frame
Neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
Neighbourhoods_venues_sorted['Neighbourhood'] = la_grouped['Neighbourhood']

for ind in np.arange(la_grouped.shape[0]):
    Neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(la_grouped.iloc[ind, :], num_top_venues)

Neighbourhoods_venues_sorted.head()

# %% [markdown]
# ### Clustering Neighbourhoods  <a name="cluster"></a>

# %% [markdown]
# The first step is to determine the optimal value of K for the dataset using the **Silhouette Coefficient Method.**
#
# A higher Silhouette Coefficient score relates to a model with better defined clusters.
#
# A higher Silhouette Coefficient indicates that the object is well matched to its own cluster and poorly matched to neighbouring clusters.

# %%
from sklearn.metrics import silhouette_score

la_grouped_clustering = la_grouped.drop('Neighbourhood', 1)

for n_cluster in range(2, 10):
    kmeans = KMeans(n_clusters=n_cluster).fit(la_grouped_clustering)
    label = kmeans.labels_
    sil_coeff = silhouette_score(la_grouped_clustering, label, metric='euclidean')
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(n_cluster, sil_coeff))

# %% [markdown]
# The Silhouette Coefficient is the highest for n_clusters=4. Therefore, the neighbourhoods shall be grouped into 4 clusters (k=4) using ***k*-means clustering.**

# %%
# set number of clusters
kclusters = 4

la_grouped_clustering = la_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(la_grouped_clustering)

# check cluster labels generated for each row in the data frame
kmeans.labels_

# %% [markdown]
# Creating a new data frame that includes the cluster as well as the top 10 venues for each neighbourhood: -

# %%
# add clustering labels
Neighbourhoods_venues_sorted.insert(0, 'Cluster Label', kmeans.labels_.astype(int))
# Neighbourhoods_venues_sorted['Cluster Label']=kmeans.labels_.astype(int)
la_merged = nhoods

# merge la_grouped with nhoods to add latitude/longitude for each Neighbourhood
la_merged = la_merged.join(Neighbourhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')
la_merged.dropna(inplace=True)
la_merged['Cluster Label'] = la_merged['Cluster Label'].astype(int)
la_merged.head()

# %% [markdown]
# Visualizing the resulting neighbourhood clusters on the map: -

# %%
import matplotlib.colors as colors
from matplotlib.colors import rgb2hex
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
rainbow[2]='#006000'
rainbow[1]='#006ff6'
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(la_merged['Latitude'], la_merged['Longitude'], la_merged['Neighbourhood'], la_merged['Cluster Label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-2],
        fill=True,
        fill_color=rainbow[cluster-2],
        fill_opacity=0.7).add_to(map_clusters)
legend_html =   '''
                <div style="position: fixed; 
                            bottom: 100px; left: 50px; width: 120px; height: 80px; 
                            border:3px solid black; z-index:9999; font-size:13px;
                            ">&nbsp; Green - Cluster 0 <br>
                              &nbsp; Red - Cluster 1 <br>
                              &nbsp; Purple - Cluster 2 <br>
                              &nbsp; Blue - Cluster 3 </i>
                </div>
                ''' 

map_clusters.get_root().html.add_child(folium.Element(legend_html))
map_clusters

# %% [markdown]
# ### Examining the Clusters

# %% [markdown]
# Creating a data frame for each cluster that includes the top 10 venues for each of its neighbourhoods: -

# %%
la_merged.loc[la_merged['Cluster Label'] == 0, la_merged.columns[[0] + list(range(4, la_merged.shape[1]))]]

# %%
la_merged.loc[la_merged['Cluster Label'] == 1, la_merged.columns[[0] + list(range(4, la_merged.shape[1]))]]

# %%
la_merged.loc[la_merged['Cluster Label'] == 2, la_merged.columns[[0] + list(range(4, la_merged.shape[1]))]]

# %%
la_merged.loc[la_merged['Cluster Label'] == 3, la_merged.columns[[0] + list(range(4, la_merged.shape[1]))]]

# %% [markdown]
# Creating a data frame grouped by clusters by taking the mean of the frequency of occurrence of each venue category: -

# %%
la_results = pd.DataFrame(kmeans.cluster_centers_)
la_results.columns = la_grouped_clustering.columns
la_results.index = ['Cluster 0','Cluster 1','Cluster 2','Cluster 3']
la_results['Total Sum'] = la_results.sum(axis = 1)
la_results

# %% [markdown]
# ### Visualizing Top 10 Venues for each Cluster  <a name="visualize"></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# %% [markdown]
# Function to generate a horizontal bar plot showing the top 10 venues for each cluster, highlighting the food venues: -

# %%
def generate_plot(clus,i):
    
    plt.style.use('default')

    tags=['Restaurant','Coffee','Food','Pizza','Sandwich']
    colors = []
    for value in clus.index: 
        if  any(t in value for t in tags):
            colors.append('#a80000')
        else:
            colors.append('#32069f')

    ax=clus.plot(kind='barh', figsize=(16,8), color=colors, alpha=0.7)

    plt.title('(in % of all venues)\n')
    ax.title.set_fontsize(14)
    plt.suptitle('Ten Most Prevalent Venues of Cluster {}'.format(i), fontsize=16)

    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

    plt.xticks([])
    ax.tick_params(axis ='both', which ='both', length = 0)
    labels = [(item.get_text()+'  ') for item in ax.get_yticklabels()]
    ax.set_yticklabels(labels)

    for label in (ax.get_yticklabels()):
        label.set_fontsize(12)

    for index, value in enumerate(clus): 
        label = "%.1f " % round(value*100,1) + "%"
        # place text at the end of bar (adding 0.001 to x, and 0.1 from y to make it appear just after the bar)
        plt.annotate(label, xy=(value + 0.001, index - 0.1), color='black',fontsize=12)

    legend_elements = [Patch(facecolor='#a80000', edgecolor='#a80000',
                             label='Food Venues',alpha=0.7),
                       Patch(facecolor='#32069f', edgecolor='#32069f',
                             label='Others',alpha=0.7)]

    ax.legend(handles=legend_elements, loc='best',fontsize=12)

    plt.show()

# %% [markdown]
# #### *Cluster 0*

# %%
cluster0=pd.DataFrame(la_results.iloc[0,0:-1]).transpose()
cluster0.sort_values(by='Cluster 0',axis=1,ascending=False,inplace=True)
display(cluster0)

clus0=cluster0.iloc[0,9::-1]
generate_plot(clus0,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-a25f3eadffc2> in <module>
# ----> 1 cluster0=pd.DataFrame(la_results.iloc[0,0:-1]).transpose()
#       2 cluster0.sort_values(by='Cluster 0',axis=1,ascending=False,inplace=True)
#       3 display(cluster0)
#       4
#       5 clus0=cluster0.iloc[0,9::-1]
#
# NameError: name 'la_results' is not defined

# %% [markdown]
# There are 6 food venues in the top 10 venues of Cluster 0 with Mexican Restaurants making up nearly 20% of all venues. These facts indicate that Cluster 0 would not be the best one to explore further in terms of setting up a new restaurant.

# %% [markdown]
# #### *Cluster 1*

# %%
cluster1=pd.DataFrame(la_results.iloc[1,0:-1]).transpose()
cluster1.sort_values(by='Cluster 1',axis=1,ascending=False,inplace=True)
display(cluster1)

clus1=cluster1.iloc[0,9::-1]
generate_plot(clus1,1)

# %% [markdown]
# There are 4 food venues in the top 10 venues of Cluster 1 with Korean Restaurants making up a huge majority (nearly 30%) of all venues. This is unsurprising as Cluster 1 consists of only two neighbourhoods, one being Koreatown and the other (Mid-Wilshire) also having a lot of Korean Restaurants. While there are only 4 food venues in the top 10, the complete dominance of Korean Restaurants in the area indicates the fact that Cluster 1 need not be looked into any further.

# %% [markdown]
# #### *Cluster 2*

# %%
cluster2=pd.DataFrame(la_results.iloc[2,0:-1]).transpose()
cluster2.sort_values(by='Cluster 2',axis=1,ascending=False,inplace=True)
cluster2.rename(columns={'Residential Building (Apartment / Condo)': 'Apartment / Condo'},inplace=True)
display(cluster2)

clus2=cluster2.iloc[0,9::-1]
generate_plot(clus2,2)

# %% [markdown]
# There are only 2 food venues in the top 10 venues of Cluster 2. To add to that, the two venues are Food Trucks and Coffee Shops as opposed to proper restaurants. There are a lot of public venues in this cluster - venues that see a lot of footfall such as parks, museums, gyms and department stores. The presence of condominium complexes in this list also suggest that the population per square unit of these neighbourhoods is high. All of these observations point in the direction of Cluster 2 being nominated as the cluster to explore further.

# %% [markdown]
# Having said that, the decision to explore Cluster 2 can only be confirmed after examining Cluster 3: -

# %% [markdown]
# #### *Cluster 3*

# %%
cluster3=pd.DataFrame(la_results.iloc[3,0:-1]).transpose()
cluster3.sort_values(by='Cluster 3',axis=1,ascending=False,inplace=True)
display(cluster3)

clus3=cluster3.iloc[0,9::-1]
generate_plot(clus3,3)

# %% [markdown]
# There are 8 food venues in the top 10 venues of Cluster 3 which is huge percentage. Except for the number 1 venue (Coffee Shops), all other food venues are proper restaurants. This clearly indicates that the neighbourhoods in Cluster 3 are saturated with restaurants already and need not be considered when opening a new restaurant.

# %% [markdown]
# It is now safe to confirm the decision of investigating **Cluster 2** further and eliminating all other clusters.

# %% [markdown]
# ### Investigating the chosen Cluster    <a name="investigate"></a>

# %%
clus2neigh=la_merged.loc[la_merged['Cluster Label'] == 2, la_merged.columns[0]].values.tolist()
clus2neigh

# %%
filtered_nhoods=nhoods.copy()

for i in range(0,len(filtered_nhoods)):

    if filtered_nhoods.iloc[i,0] not in clus2neigh:
        filtered_nhoods.iloc[i,0]='TO DROP'

# %%
filtered_nhoods=filtered_nhoods[filtered_nhoods.Neighbourhood!='TO DROP']
filtered_nhoods.reset_index(drop=True,inplace=True)

# %% [markdown]
# The neighbourhoods in Cluster 2 along with their coordinates: -

# %%
filtered_nhoods

# %% [markdown]
# Function to obtain and display the closest Vegan/vegetarian restaurants from each neighbourhood in Cluster 2 and the corresponding distances: -

# %%
def get_neigh_vegan(url1):
    
    results = requests.get(url1).json()

    # assign relevant part of JSON to venues
    venues = results['response']['venues']

    # tranform venues into a data frame
    dataframe = json_normalize(venues)

    # keep only columns that include venue name, and anything that is associated with location
    filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
    dataframe_filtered = dataframe.loc[:, filtered_columns]

    # filter the category for each row
    dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

    # clean column names by keeping only last term
    dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
    
    display(dataframe_filtered.loc[:,['name','categories','distance','lat','lng']])

# %%
category='4bf58dd8d48988d1d3941735'#The category for vegan/vegetarin restaurants obtained from https://developer.foursquare.com/docs/resources/categories
radius = 700
LIMIT=30

# %%
for n in range(0,len(filtered_nhoods)):
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    filtered_nhoods.iloc[n,1], 
    filtered_nhoods.iloc[n,2], 
    VERSION, 
    category, 
    radius, 
    LIMIT)
    print('------------------------------------------------- '+ filtered_nhoods.iloc[n,0] + ' -------------------------------------------------')
    get_neigh_italian(url)
    print('\n\n')g

# %% [markdown]
#  From the data frames above, it can be observed that Park La Brea has 7 Restaurants within 700 meters from its center. Hancock Park has fewer (3) but two of them are less than 250 meters away from its center. This indicates that Park La Brea and Hancock Park would not be suitable neighbourhoods to open a Restaurant and can therefore be eliminated. This leaves the following neighbourhoods: -

# %%
filter2_nhoods=filtered_nhoods[(filtered_nhoods.Neighbourhood !='Park La Brea') & (filtered_nhoods.Neighbourhood !='Hancock Park')]
filter2_nhoods.reset_index(drop=True,inplace=True)
filter2_nhoods

# %% [markdown]
# Computing the distance of each neighbourhood from the center of LA and adding it as a column to the existing data frame: -

# %%
filter2_nhoods = filter2_nhoods.reindex( columns = filter2_nhoods.columns.tolist() + ['Distance from LA center (in km)'])  #this way to avoid warnings

# %%
from math import radians, sin, cos, acos

slat = radians(34.0536909) #LA center Latitude obtained earlier
slon = radians(-118.2427666) #LA center Longitude obtained earlier

# %%
for n in range(0,len(filter2_nhoods)):
    
    elat = radians(filter2_nhoods.iloc[n,1])
    elon = radians(filter2_nhoods.iloc[n,2])

    dist = 6371.01 * acos(sin(slat)*sin(elat) + cos(slat)*cos(elat)*cos(slon - elon))
    filter2_nhoods.loc[n,'Distance from LA center (in km)']=dist

# %%
filter2_nhoods.sort_values(by='Distance from LA center (in km)',inplace=True)
filter2_nhoods.reset_index(drop=True,inplace=True)
filter2_nhoods

# %% [markdown]
# It is clear from the data frame above that **Exposition Park** (6km) and **Montecito Heights** (6km) are much closer to the center of Los Angeles than Wilshire Center (17.5km) and Playa Vista (19km). Since the distance from LA center is a criterion in choosing the optimal neighbourhood, Wilshire Center and Playa Vista would not be appropriate choices.

# %% [markdown]
# ### Web Scraping Rent Data  <a name="rent"></a>

# %% [markdown]
# The list of average rent of all neighbourhoods in LA can be obtained by scraping the relevant webpage. The data in the webpage is in the form of a table. Therefore, the data can be obtained much more easily.

# %%
url = requests.get('https://www.rentcafe.com/average-rent-market-trends/us/ca/los-angeles/').text
soup = BeautifulSoup(url,"html.parser")

# %%
table = soup.find('table',id="MarketTrendsAverageRentTable")
pr = table.find_all('td')
nh = table.find_all('th')

# %%
price = []
neighbourhood = []

for i in range(0, len(pr)):
    price.append(pr[i].text.strip())
    neighbourhood.append(nh[i+2].text.strip())
        
df_rent = pd.DataFrame(data=[neighbourhood, price]).transpose()
df_rent.columns = ['Neighbourhood', nh[1].text]
df_rent.loc[32,'Neighbourhood']='Montecito Heights' #Correcting a spelling error
df_rent

# %% [markdown]
# The above data frame is already in ascending order of average rent. The 2 neighbourhoods in question can be identified from the table and their average rents displayed: -

# %%
df_rent[(df_rent['Neighbourhood']=='Exposition Park') | (df_rent['Neighbourhood']=='Montecito Heights')]

# %% [markdown]
# The average rent in Exposition Park is nearly two times the average rent in Montecito Heights. This means that Exposition Park is a significantly more expensive neighbourhood.

# %% [markdown]
# ## <u>Results and Discussion</u><a name="results"></a>

# %% [markdown]
#  <p style='text-align: justify;'>In the beginning of the analysis the data frame of Los Angeles neighbourhoods was trimmed to include only the ones that had 10 or more venues. This decision was taken as it made sense to set up a restaurant in one of the more popular neighbourhoods, thereby attracting the attention of a lot more people.</p>
#
# <p style='text-align: justify;'>When clustering the neighbourhoods, the optimal value of k (k=4) for the dataset was arrived at using the Silhouette Coefficient Method. As a consequence, all neighbourhoods were grouped into 4 clusters using k-means clustering. In order to examine the deterministic characteristics of each cluster, a data frame for each cluster was created that included their most frequently occurring venues in descending order. A horizontal bar plot was generated showing the top 10 venues for each cluster, highlighting the food venues. This helped in determining the optimal cluster for further analysis. All of the observations pointed in the direction of Cluster 2 being that cluster. It had only 2 food venues amongst the top 10 - food trucks and coffee shops - which were not full-fledged restaurants. The cluster also had apartment complexes and a lot of public venues which meant that the neighbourhoods in it see a lot of people.</p>
#
# <p style='text-align: justify;'>The following step was to obtain and display the closest restaurants from each neighbourhood in Cluster 2 and their corresponding distances. It was observed that Park La Brea has 7 Restaurants within 700 meters from its center. Hancock Park had fewer (3) but two of them were less than 250 meters away from its center. This indicated that Park La Brea and Hancock Park would not be suitable neighbourhoods to open a Restaurant in and were eliminated. </p>
#
# <p style='text-align: justify;'>The next criteria was the distance of each of the remaining neighbourhoods from the center of the city. It was found that Exposition Park (~6km) and Montecito Heights (~6km) are much closer to the center of Los Angeles than Wilshire Center (~17.5km) and Playa Vista (~19km). Therefore, it was understood that Wilshire Center and Playa Vista would not be appropriate choices.</p>
#
# <p style='text-align: justify;'>The table of average rent of all neighbourhoods in LA was obtained by scraping the relevant webpage. The two neighbourhoods that remained in contention were identified from the table and their average rents displayed. It was detected that the average rent in Exposition Park is nearly two times the average rent in Montecito Heights, implying that Exposition Park is a significantly more expensive neighbourhood. However, this does not automatically mean Montecito Heights is the better option. A factor to consider is the type of restaurant the shareholder is interested in setting up. If, for example, a high-end fine dining restaurant needs to be set up, a neighbourhood that has a low average rent would not work. The reason for this is that such a neighbourhood would generally be home to people with lower income and a high-end fine dining restaurant may not see a healthy influx of people. On the other hand, if a fast-casual/casual dining restaurant needs to be set up, a high-rent neighbourhood would not be ideal simply because the restaurant will not be able to afford the rented space. While average rent can point in the direction of the right neighbourhood, a final decision cannot be made without all the required information. </p>

# %% [markdown]
# ## <u>Conclusion</u><a name="conclusion"></a>

# %% [markdown]
# <div style="text-align: justify"> The objective of this project was to identify the best potential neighbourhoods in Los Angeles where a vegan/vegetarian restaurant can be set up. All the required neighbourhood data was either scraped of the internet or obtained using a geolocator. After the neighbourhoods were visualized on a folium map, their venues were explored using Foursquare location data. Based on the frequency of occurrences of different venue types, the neighbourhoods were divided into four groups with the help of k-means clustering. The clusters were examined and the best one in which a restaurant could be set up was chosen. The neighbourhoods were filtered further based on proximity to existing vegan restaurants and distance from the center of the city. The analysis brought the number of contenders down to two neighbourhoods - **Exposition Park** and **Montecito Heights**. Average neighbourhood rent data was called upon and while it provided interesting insights, it could not influence the decision only with the information at hand. As touched upon earlier, the results of the analysis highlight potential neighbourhoods where a vegan/vegetarian restaurant may be opened solely based on geographical location and proximity to competitors. This will only serve as a starting point in the overall investigation since there are a lot of other factors - availability of commercial spaces, appeal of each location, proximity to major roads, access through public transport, etc. - that influence such a decision. </div>

# %% [markdown]
# [Back to top of notebook](#top)
